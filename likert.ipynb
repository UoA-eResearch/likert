# %%
import pandas as pd
pd.set_option("display.max_columns", None)
pre = pd.read_csv("data/dmp-prepilot.csv", encoding_errors="ignore")
pre
# Out:
#     ID         Start time    Completion time      Email  Name  \
# 0   10   8/15/23 17:13:49   8/15/23 17:19:26  anonymous   NaN
# 1   11   8/15/23 17:32:50   8/15/23 17:34:38  anonymous   NaN
# 2   12   8/15/23 19:41:58   8/15/23 19:45:51  anonymous   NaN
# 3   13   8/15/23 20:35:19   8/15/23 20:36:57  anonymous   NaN
# 4   14    8/16/23 9:43:40    8/16/23 9:45:50  anonymous   NaN
# 5   15   8/16/23 11:44:46   8/16/23 11:53:27  anonymous   NaN
# 6   16   8/16/23 15:09:01   8/16/23 15:11:53  anonymous   NaN
# 7   17   8/16/23 16:17:33   8/16/23 16:20:39  anonymous   NaN
# 8   18    8/17/23 9:35:40    8/17/23 9:38:41  anonymous   NaN
# 9   19   8/17/23 10:36:57   8/17/23 10:40:05  anonymous   NaN
# 10  20   8/17/23 14:56:28   8/17/23 14:57:41  anonymous   NaN
# 11  21   8/17/23 21:22:02   8/17/23 21:35:44  anonymous   NaN
# 12  22   8/21/23 11:56:54   8/21/23 12:00:45  anonymous   NaN
# 13  23   8/21/23 13:41:22   8/21/23 13:46:26  anonymous   NaN
# ...

# %%
post = pd.read_csv("data/dmp-postpilot.csv", encoding_errors="ignore").dropna()
post
# Out:
#    Enter your DMP pilot code (This will be used to pair your pre- and post-pilot survey responses).  \
# 0                                               DMP01
# 1                                               DMP05
# 2                                               DMP10
# 3                                               DMP16
# 4                                               DMP03
# 5                                               DMP14
# 6                                               DMP09
# 7                                               DMP07
# 8                                               DMP15
# 9                                               DMP13
# 10                                              DMP19
# 11                                              DMP18
#
#    CARE principles Copyright for data Data publishing Data sharing agreements  \
# 0             Good               Good       Excellent                    Good
# ...
