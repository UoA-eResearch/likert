# %%
import pandas as pd
import matplotlib.pyplot as plt
import plot_likert
plot_likert.__internal__.BAR_LABEL_FORMAT = "%.0f"
from plot_likert import plot_likert
pd.set_option("display.max_columns", None)
pre = pd.read_csv("data/Data Management Planning (DMP) pre-pilot survey.csv", index_col=0).drop(columns="Indigenous data sovereignty, including for Māori and Pacific peoples")
pre.columns = pd.Series(pre.columns).apply(lambda c: c.strip("\xa02") + " (pre)")
post = pd.read_csv("data/Data Management Planning (DMP) post-pilot survey.csv", encoding_errors="ignore", index_col=0)
post.columns = pd.Series(post.columns).apply(lambda c: c.strip("\xa0") + " (post)")
df = pd.concat([pre, post], axis=1)
df = df[~df.index.isna()]
df["dummy"] = pd.NA
df
# Out:
#       CARE principles (pre) Copyright for data (pre) Data publishing (pre)  \
# DMP01                  Good                     Good             Excellent
# DMP05               Minimal                     Fair                  Fair
# DMP10          No awareness                  Minimal                  Fair
# DMP16               Minimal                     Fair                  Fair
# DMP03          No awareness                     Fair               Minimal
# DMP14                  Good             No awareness               Minimal
# DMP09          No awareness                     Fair                  Fair
# DMP07          No awareness                  Minimal                  Good
# DMP15                  Good                     Good                  Good
# DMP13                  Fair                     Good                  Good
# DMP19          No awareness             No awareness          No awareness
# ...

# %%
cols = []
for i in range(len(pre.columns)):
  cols.append(pre.columns[i])
  cols.append(post.columns[i])
  cols.append("dummy")
cols
# Out:
# ['CARE principles (pre)',
#  'CARE principles (post)',
#  'dummy',
#  'Copyright for data (pre)',
#  'Copyright for data (post)',
#  'dummy',
#  'Data publishing (pre)',
#  'Data publishing (post)',
#  'dummy',
#  'Data sharing agreements (pre)',
#  'Data sharing agreements (post)',
#  'dummy',
#  'Ethical requirements for research (pre)',
#  'Ethical requirements for research (post)',
#  'dummy',
#  'FAIR principles (pre)',
#  'FAIR principles (post)',
#  'dummy',
#  'Indigenous data sovereignty, including for Māori and Pacific peoples (pre)',
#  'Indigenous data sovereignty, including for Māori and Pacific peoples (post)',
#  'dummy',
#  'Intellectual property (pre)',
#  'Intellectual property (post)',
#  'dummy',
#  'Open Access publishing (pre)',
#  'Open Access publishing (post)',
#  'dummy',
#  'Privacy concerns around data (pre)',
#  'Privacy concerns around data (post)',
#  'dummy',
#  'Research Data Management Planning (pre)',
#  'Research Data Management Planning (post)',
# ...

# %%
df = df[cols]
df
# Out:
#       CARE principles (pre) CARE principles (post) dummy  \
# DMP01                  Good                   Good  <NA>
# DMP05               Minimal                   Good  <NA>
# DMP10          No awareness                   Fair  <NA>
# DMP16               Minimal                Minimal  <NA>
# DMP03          No awareness                   Good  <NA>
# DMP14                  Good                   Good  <NA>
# DMP09          No awareness                   Fair  <NA>
# DMP07          No awareness                   Fair  <NA>
# DMP15                  Good              Excellent  <NA>
# DMP13                  Fair                   Good  <NA>
# DMP19          No awareness                   Good  <NA>
# DMP18               Minimal                Minimal  <NA>
# DMP17                  Fair                   Good  <NA>
# DMP02               Minimal              Excellent  <NA>
# DMP08                  Good                    NaN  <NA>
# ...

# %%
scale = ['No awareness', 'Minimal', 'Fair', 'Good', 'Excellent']
colors = ["#ffffff00", '#e66101','#fdb863','#f7f7f7','#b2abd2','#5e3c99']

# %%
plt.rcParams['figure.figsize'] = (10,10)
#plt.rcParams['figure.dpi'] = 200
ax = plot_likert(df, scale, colors=colors, plot_percentage=True, bar_labels=True, bar_labels_color="black", title=f"Data Management Planning (DMP) pilot survey", legend=False, width=1)
ax.set_yticklabels(label.get_text().replace("(post)", "").replace("(pre)", "") for label in ax.get_yticklabels())
ax.set_yticks(ax.get_yticks()[2::3])
plt.show()

ax = plot_likert(df.dropna(subset="Working with sensitive data (post)"), scale, colors=colors, plot_percentage=True, bar_labels=True, bar_labels_color="black", title=f"Data Management Planning (DMP) pilot survey", legend=False, width=1)
ax.set_yticklabels(label.get_text().replace("(post)", "").replace("(pre)", "") for label in ax.get_yticklabels())
ax.set_yticks(ax.get_yticks()[2::3])
plt.show()
# Out:
# /home/nyou045/git/plot-likert/plot_likert/plot_likert.py:321: UserWarning: In your data, not all questions have the same number of responses. i.e., different numbers of people answered each question. Therefore, the percentages aren't directly comparable: X% for one question represents a different number of responses than X% for another question, yet they will appear the same in the percentage graph. This may be misleading to your reader.
#   warn(
# /home/nyou045/git/plot-likert/plot_likert/plot_likert.py:321: UserWarning: In your data, not all questions have the same number of responses. i.e., different numbers of people answered each question. Therefore, the percentages aren't directly comparable: X% for one question represents a different number of responses than X% for another question, yet they will appear the same in the percentage graph. This may be misleading to your reader.
#   warn(

# %%
phd = ["DMP03", "DMP09", "DMP10", "DMP16", "DMP17"]
ax = plot_likert(df[df.index.isin(phd)], scale, colors=colors, plot_percentage=True, bar_labels=True, bar_labels_color="black", title=f"Data Management Planning (DMP) pilot survey", legend=False, width=1)
ax.set_yticklabels(label.get_text().replace("(post)", "").replace("(pre)", "") for label in ax.get_yticklabels())
ax.set_yticks(ax.get_yticks()[2::3])
plt.show()
# Out:
# /home/nyou045/git/plot-likert/plot_likert/plot_likert.py:321: UserWarning: In your data, not all questions have the same number of responses. i.e., different numbers of people answered each question. Therefore, the percentages aren't directly comparable: X% for one question represents a different number of responses than X% for another question, yet they will appear the same in the percentage graph. This may be misleading to your reader.
#   warn(

# %%
handles,labels = ax.get_legend_handles_labels()
fig_legend = plt.figure(figsize=(2,2))
fig_legend.legend(handles, labels, loc='center')
plt.axis("off")
# Out:
# (0.0, 1.0, 0.0, 1.0)
